# %%
# ALTERNATIVE: Simple Installation (if above fails)
# Run these commands one by one if you encounter dependency conflicts:

# Step 1: Restart Runtime first (Runtime -> Restart Runtime)
# Step 2: Run this cell
# !pip install torch==2.6.0 torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124

# Step 3: Run this cell  
# !pip install unsloth[colab-new]@git+https://github.com/unslothai/unsloth.git

# Step 4: Run this cell
# !pip install trl peft accelerate bitsandbytes

print("✅ Manual installation completed! Now run the main training cell below.")

# %%
# !pip install unsloth trl peft accelerate bitsandbytes

# QUICK START: Saudi HR CV Scoring Model
# Copy this entire code into a Google Colab cell and run it
# Make sure you have T4 GPU enabled and uploaded your JSON file

# Step 2: Import libraries
import torch
import json
from datasets import Dataset
from transformers import TrainingArguments
from trl import SFTTrainer
from unsloth import FastLanguageModel

# Step 3: Load model (try alternatives if this doesn't work)
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name="unsloth/Meta-Llama-3.1-8B-bnb-4bit",  # Alternative: "unsloth/llama-3-8b-instruct-bnb-4bit"
    max_seq_length=2048,
    dtype=None,
    load_in_4bit=True,
)

# Step 4: Setup for fine-tuning
model = FastLanguageModel.get_peft_model(
    model, r=16, target_modules=["q_proj", "k_proj", "v_proj", "o_proj", "gate_proj", "up_proj", "down_proj"],
    lora_alpha=16, lora_dropout=0, bias="none", use_gradient_checkpointing="unsloth", random_state=3407,
)


# Step 5: Load your dataset (updated to use new format)
with open('saudi_hr_alpaca_dataset_new.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Step 6: Format dataset
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

def format_prompts(examples):
    texts = []
    for instruction, input_text, output in zip(examples["instruction"], examples["input"], examples["output"]):
        text = alpaca_prompt.format(instruction, input_text, output) + tokenizer.eos_token
        texts.append(text)
    return {"text": texts}

dataset = Dataset.from_list(data).map(format_prompts, batched=True)

# Step 7: Train the model
trainer = SFTTrainer(
    model=model, tokenizer=tokenizer, train_dataset=dataset, dataset_text_field="text",
    max_seq_length=2048, dataset_num_proc=2, packing=False,
    args=TrainingArguments(
        per_device_train_batch_size=2, gradient_accumulation_steps=4, warmup_steps=5,
        max_steps=60, learning_rate=2e-4, fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(), logging_steps=1, optim="adamw_8bit",
        weight_decay=0.01, lr_scheduler_type="linear", seed=3407, output_dir="outputs",
        report_to="none", save_strategy="steps", save_steps=20, dataloader_num_workers=0,
    ),
)

print("🚀 Starting training...")
trainer.train()
print("✅ Training completed!")

# Step 8: Test the model with new JSON format
def score_application(application_json):
    """Score a job application using the new JSON format"""
    instruction = "Rate this job application against the job posting on a scale of 1-10 and provide a brief explanation for the Saudi HR market context."
    input_text = f"Job Application Data: {json.dumps(application_json)}"
    prompt = alpaca_prompt.format(instruction, input_text, "")

    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=256, temperature=0.7, do_sample=True, pad_token_id=tokenizer.eos_token_id)

    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response.split("### Response:")[-1].strip()

# Legacy function for backward compatibility
def score_cv(job_posting, cv_details):
    instruction = "Rate this CV against the job posting on a scale of 1-10 and provide a brief explanation for the Saudi HR market context."
    input_text = f"Job Posting: {job_posting}\n\nCV:\n{cv_details}"
    prompt = alpaca_prompt.format(instruction, input_text, "")

    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
    with torch.no_grad():
        outputs = model.generate(**inputs, max_new_tokens=256, temperature=0.7, do_sample=True, pad_token_id=tokenizer.eos_token_id)

    response = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return response.split("### Response:")[-1].strip()

# Step 9: Save model
model.save_pretrained("saudi_hr_model")
tokenizer.save_pretrained("saudi_hr_model")
print("💾 Model saved!")

# Step 10: Test with example using new JSON format
test_application = {
    "application": {
        "nationality": "Saudi Arabian",
        "address": "Riyadh, Saudi Arabia",
        "skills": "Python,JavaScript,React,Node.js,Arabic Localization",
        "education": [{
            "institution": "King Saud University",
            "degree": "Bachelor",
            "field_of_study": "Computer Science",
            "start_year": 2018,
            "end_year": 2022,
            "description": "Computer science with focus on software engineering and web development"
        }],
        "experiences": [{
            "company_name": "Saudi Tech Startup",
            "job_title": "Software Developer",
            "start_year": 2022,
            "end_year": None,
            "is_current": 1,
            "description": "Full-stack development using modern frameworks and technologies"
        }],
        "languages": [
            {"name": "Arabic", "proficiency": "native"},
            {"name": "English", "proficiency": "advanced"}
        ],
        "job_posting": {
            "name": "Software Engineer - Riyadh Tech Company",
            "employment_type": "full_time",
            "is_remote": 0,
            "required_years_of_experience": 3
        }
    }
}

result = score_application(test_application)
print("🎯 Test Result with New JSON Format:")
print(result)
print("\n🎉 Your Saudi HR application scoring model is ready to use!")
print("Use: score_application(application_json) to score any application")
print("Or use legacy: score_cv(job_posting, cv_details) for old format")

import random
import re

# Step 9: EVALUATION FUNCTION - Test with 30 samples (updated for new format)
def test_model_with_samples():
    """Test the fine-tuned model with 30 random samples from the dataset"""
    print("\n🧪 TESTING MODEL WITH 30 SAMPLES")
    print("=" * 50)

    # Get 30 random samples
    random.seed(42)  # For reproducible results
    samples = random.sample(data, min(30, len(data)))

    correct_predictions = 0
    total_score_diff = 0

    for i, sample in enumerate(samples, 1):
        print(f"\n📋 TEST {i}/30")
        print("-" * 30)

        # Parse the input to extract application JSON
        input_text = sample['input']
        
        # Extract JSON from the input string
        json_start = input_text.find('{')
        json_str = input_text[json_start:]
        
        try:
            application_data = json.loads(json_str)
            
            # Get model prediction using new function
            model_prediction = score_application(application_data)
            
            # Extract scores from text
            def extract_score(text):
                score_match = re.search(r'Score:\s*(\d+\.?\d*)/10', text)
                return float(score_match.group(1)) if score_match else 0.0

            expected_score = extract_score(sample['output'])
            predicted_score = extract_score(model_prediction)

            # Calculate difference
            score_diff = abs(expected_score - predicted_score)
            total_score_diff += score_diff

            # Check if prediction is good (within 1 point)
            if score_diff <= 1.0:
                correct_predictions += 1
                status = "✅ GOOD"
            else:
                status = "❌ NEEDS WORK"

            # Show results
            app_info = application_data.get('application', {})
            job_info = app_info.get('job_posting', {})
            print(f"📝 Job: {job_info.get('name', 'Unknown')[:100]}...")
            print(f"👤 Applicant: {app_info.get('nationality', 'Unknown')} - {app_info.get('skills', '')[:50]}...")
            print(f"\n✅ Expected: {sample['output']}")
            print(f"🤖 Model Got: {model_prediction}")
            print(f"\n📊 Scores: Expected {expected_score}/10, Got {predicted_score}/10")
            print(f"📈 Difference: {score_diff:.1f} points - {status}")
            
        except json.JSONDecodeError:
            print(f"❌ Error parsing JSON for sample {i}")
            continue

    # Final results
    accuracy = (correct_predictions / len(samples)) * 100
    avg_diff = total_score_diff / len(samples)

    print(f"\n🎯 FINAL RESULTS")
    print("=" * 50)
    print(f"📊 Accuracy: {accuracy:.0f}% ({correct_predictions}/{len(samples)} within 1 point)")
    print(f"📈 Average Score Difference: {avg_diff:.2f} points")

    if accuracy >= 80:
        print("🎉 EXCELLENT! Model is performing very well!")
    elif accuracy >= 60:
        print("👍 GOOD! Model is performing reasonably well")
    elif accuracy >= 40:
        print("⚠️ FAIR! Model needs some improvement")
    else:
        print("❌ POOR! Model needs significant improvement")

    return {
        'accuracy': accuracy,
        'avg_difference': avg_diff,
        'correct_predictions': correct_predictions,
        'total_samples': len(samples)
    }

# Step 10: Run the evaluation
evaluation_results = test_model_with_samples()

# Step 11: Export to GGUF format with proper error handling
def export_gguf_model():
    """Export the fine-tuned model to GGUF format"""
    try:
        print("🔄 Exporting model to GGUF format...")
        
        # Save in GGUF format with different quantization options
        quantization_methods = ["q4_k_m", "q8_0", "f16"]
        
        for method in quantization_methods:
            try:
                print(f"📦 Trying quantization method: {method}")
                model.save_pretrained_gguf(
                    "saudi_hr_gguf", 
                    tokenizer, 
                    quantization_method=method
                )
                print(f"✅ Successfully exported with {method} quantization!")
                
                # List the generated files
                import os
                if os.path.exists("saudi_hr_gguf"):
                    files = os.listdir("saudi_hr_gguf")
                    print(f"📁 Generated files: {files}")
                    
                    # Find the GGUF file
                    gguf_files = [f for f in files if f.endswith('.gguf')]
                    if gguf_files:
                        print(f"🎯 GGUF file created: {gguf_files[0]}")
                        return f"saudi_hr_gguf/{gguf_files[0]}"
                    else:
                        print("⚠️ No .gguf file found in output directory")
                
                break
                
            except Exception as e:
                print(f"❌ Failed with {method}: {str(e)}")
                if method == quantization_methods[-1]:  # Last method
                    raise e
                continue
        
    except Exception as e:
        print(f"❌ GGUF export failed: {str(e)}")
        print("💡 Trying alternative export method...")
        
        # Alternative: Save as regular model first, then convert
        try:
            model.save_pretrained("saudi_hr_model_temp")
            tokenizer.save_pretrained("saudi_hr_model_temp")
            
            # Try to load and convert
            from unsloth import FastLanguageModel
            temp_model, temp_tokenizer = FastLanguageModel.from_pretrained("saudi_hr_model_temp")
            temp_model.save_pretrained_gguf("saudi_hr_gguf_alt", temp_tokenizer, quantization_method="q4_k_m")
            
            print("✅ Alternative GGUF export successful!")
            return "saudi_hr_gguf_alt/unsloth.Q4_K_M.gguf"
            
        except Exception as e2:
            print(f"❌ Alternative export also failed: {str(e2)}")
            print("💾 Saving as regular PyTorch model instead...")
            model.save_pretrained("saudi_hr_model_final")
            tokenizer.save_pretrained("saudi_hr_model_final")
            return None

# Export the model
gguf_path = export_gguf_model()

# Step 12: Save to Google Drive with error handling
def save_to_drive():
    """Save the model to Google Drive"""
    try:
        from google.colab import drive
        drive.mount('/content/drive')
        
        # Create directory if it doesn't exist
        import os
        drive_path = '/content/drive/MyDrive/saudi_hr_model/'
        os.makedirs(drive_path, exist_ok=True)
        
        if gguf_path and os.path.exists(gguf_path):
            # Copy GGUF file
            import shutil
            filename = os.path.basename(gguf_path)
            shutil.copy(gguf_path, f"{drive_path}{filename}")
            print(f"✅ GGUF model saved to: {drive_path}{filename}")
            
        else:
            # Copy regular model files
            import shutil
            if os.path.exists("saudi_hr_model_final"):
                shutil.copytree("saudi_hr_model_final", f"{drive_path}pytorch_model", dirs_exist_ok=True)
                print(f"✅ PyTorch model saved to: {drive_path}pytorch_model/")
            
            if os.path.exists("saudi_hr_gguf"):
                shutil.copytree("saudi_hr_gguf", f"{drive_path}gguf_model", dirs_exist_ok=True) 
                print(f"✅ GGUF files saved to: {drive_path}gguf_model/")
        
        print("💾 Model backup completed!")
        
    except Exception as e:
        print(f"⚠️ Drive save failed: {str(e)}")
        print("📁 Your model is still available in the local session:")
        print("   - Regular model: saudi_hr_model_final/")
        print("   - GGUF model: saudi_hr_gguf/")

# Save to drive
save_to_drive()

print("🎉 Training and export completed!")
print("📋 Summary:")
print(f"   - Evaluation accuracy: {evaluation_results.get('accuracy', 0):.1f}%")
print(f"   - Model format: {'GGUF + PyTorch' if gguf_path else 'PyTorch only'}")
print("   - Location: Google Drive and local session")
